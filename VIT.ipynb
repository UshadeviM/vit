# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from transformers import ViTFeatureExtractor, ViTForImageClassification
import torch.nn as nn
import torchvision.transforms as transforms

# Load the dataset
data_path = '/content/drive/MyDrive/Colab Notebooks/Monument_dataset_new/Images'
labels_file = '/content/drive/MyDrive/Colab Notebooks/Monument_dataset_new/Groundtruth values/labels.xlsx'
labels_df = pd.read_excel(labels_file)

labels_df['Image ID'] = labels_df['Image ID'].astype(str)
extra_columns = ['Latitude', 'Longitude', 'State', 'City', 'Description', 'Architecture Style']
images = [os.path.join(data_path, f"image{img}.png") for img in labels_df['Image ID'].tolist()]
labels = labels_df['Monument Name'].tolist()
label_mapping = {label: idx for idx, label in enumerate(set(labels))}
encoded_labels = [label_mapping[label] for label in labels]

# Splitting Into  training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, encoded_labels, test_size=0.2, random_state=42)


transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10)

])

class MonumentDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert('RGB')
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label
train_dataset = MonumentDataset(X_train, y_train, transform=transform)
test_dataset = MonumentDataset(X_test, y_test, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

#ViT
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224', num_labels=len(label_mapping), ignore_mismatched_sizes=True)



optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()

# Training loop
def train(model, train_loader, optimizer, criterion, num_epochs=5):
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images).logits
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_loader):.4f}')

def get_monument_details(monument_name, labels_df):
    details = labels_df[labels_df['Monument Name'] == monument_name][extra_columns].iloc[0].to_dict()
    return details
def evaluate(model, test_loader, label_mapping, labels_df):
    model.eval()
    all_preds = []
    all_labels = []
    inv_label_mapping = {v: k for k, v in label_mapping.items()}  # To map index back to monument name

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images).logits
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels)

    accuracy = accuracy_score(all_labels, all_preds)
    for pred in all_preds:
        monument_name = inv_label_mapping[pred]
        details = get_monument_details(monument_name, labels_df)
        print(f"Monument: {monument_name}, Details: {details}")

    return accuracy

# Training the model
train(model, train_loader, optimizer, criterion, num_epochs=5)

# Evaluating the model
accuracy = evaluate(model, test_loader, label_mapping, labels_df)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([48]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([48, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch [1/5], Loss: 2.6738
# Epoch [2/5], Loss: 0.5358
# Epoch [3/5], Loss: 0.1035
# Epoch [4/5], Loss: 0.0397
# Epoch [5/5], Loss: 0.0280
# Monument: Brihadisvara Temple, Details: {'Latitude': 10.78257995, 'Longitude': 79.13138189, 'State': 'Tamil Nadu', 'City': 'Thanjavur', 'Description': "The Brihadisvara Temple, a UNESCO World Heritage Site, is a magnificent example of Dravidian architecture and a testament to the Chola dynasty's grandeur. Built in the 11th century, it features a massive temple complex with intricate sculptures, towering gopurams (gateway towers), and a monumental vimana (temple tower).", 'Architecture Style': 'The temple showcases Dravidian architecture, characterized by its towering vimana, intricate stone carvings, and grand scale, reflecting the artistic and engineering prowess of the Chola period.'}
# Monument: Sanchi Stupa, Details: {'Latitude': 23.4806919, 'Longitude': 77.73629684, 'State': 'Madhya Pradesh', 'City': 'The Sanchi Stupa is a UNESCO World Heritage Site, renowned for its ancient Buddhist architecture and historical significance. Built during the Mauryan period, it features a large hemispherical dome and intricately carved gateways, symbolizing the importance of Buddhist teachings and the life of Buddha.', 'Description': 'The stupa exemplifies Buddhist architecture, characterized by its dome-shaped structure, elaborate stone carvings, and symbolic representation of the Buddha’s teachings.', 'Architecture Style': nan}
# Monument:  Meenakshi Temple, Details: {'Latitude': 12.8749691, 'Longitude': 77.5950421, 'State': 'Tamil Nadu', 'City': 'Madurai', 'Description': 'The Meenakshi Temple is an ancient and iconic Hindu temple dedicated to Goddess Meenakshi and Lord Sundareswarar. It is famous for its towering gopurams (gateway towers) adorned with intricate carvings and vibrant sculptures.', 'Architecture Style': 'Dravidian architecture, known for its monumental towers, intricate stone carvings, and elaborate sculptures depicting mythological figures.'}
# Monument: Pattadakal, Details: {'Latitude': 15.9488, 'Longitude': 75.8164, 'State': 'Karnataka', 'City': 'Pattadakal', 'Description': "Pattadakal is a UNESCO World Heritage Site renowned for its group of 7th and 8th-century temples that display a blend of North Indian (Nagara) and South Indian (Dravidian) architectural styles, reflecting the Chalukyan dynasty's artistic achievements. It served as a royal ceremonial center for coronations.", 'Architecture Style': 'Pattadakal exhibits a fusion of Dravidian and Nagara architectural styles, with intricately carved sandstone temples.'}
# Monument: Lotus Temple, Details: {'Latitude': 28.5535, 'Longitude': 77.2588, 'State': 'Delhi', 'City': 'New Delhi', 'Description': "The Lotus Temple, located in New Delhi, is a Bahá'í House of Worship known for its distinctive lotus-shaped design.", 'Architecture Style': 'It exemplifies modern architectural style with its 27 free-standing marble-clad petals, symbolizing purity and unity, inviting people of all faiths to meditate and reflect in a serene environment.'}
# Monument: Rashtrapati Bhawan, Details: {'Latitude': 28.6143, 'Longitude': 77.1994, 'State': 'Delhi', 'City': 'New Delhi', 'Description': 'Rashtrapati Bhawan, the official residence of the President of India, is an architectural marvel that combines Indian and Western styles, set within extensive gardens. Designed by architect Edwin Lutyens, it symbolizes the grandeur of colonial architecture and Indian heritage.', 'Architecture Style': 'The building features a Neo-Classical architectural style with elements of Mughal architecture, characterized by its large dome, imposing columns, and elaborate ornamental details.'}
# Monument: Khajuraho Temples, Details: {'Latitude': 24.85326945, 'Longitude': 79.9209008622041, 'State': 'Madhya Pradesh', 'City': 'Khajuraho', 'Description': 'The Khajuraho Temples are a group of stunning Hindu and Jain temples built between 950 and 1050 AD during the rule of the Chandela dynasty', 'Architecture Style': 'Nagara architectural style, characterized by soaring spires (shikharas) and detailed carvings that depict various aspects of life, including love, spirituality, and mythology.'}
# Monument: Golconda Fort Hyderabad, Details: {'Latitude': 17.3833665, 'Longitude': 78.4010991, 'State': 'Telangana', 'City': 'Hyderabad', 'Description': 'Golconda Fort is a historic fortress renowned for its impressive architecture, sprawling complex, and strategic location atop a hill. Built during the Qutb Shahi dynasty, it features magnificent gates, palaces, and a unique acoustic system, showcasing the ingenuity of ancient engineering.', 'Architecture Style': 'The fort exhibits Indo-Islamic architecture, characterized by its massive stone walls, intricate carvings, and a blend of Persian and Indian architectural elements.'}
# Monument:  Hawa Mahal Jaipur , Details: {'Latitude': 26.923932, 'Longitude': 75.8268652, 'State': 'Rajasthan', 'City': 'Jaipur', 'Description': 'Hawa Mahal, also known as the "Palace of Winds," is a five-story palace made of red and pink sandstone, built in 1799 by Maharaja Sawai Pratap Singh. It features over 900 small windows (jharokhas) designed for the royal women to observe street life without being seen', 'Architecture Style': 'The architectural style blends Rajput and Mughal influences.'}
# Monument: Basilica of Bom Jesus, Details: {'Latitude': 15.5009, 'Longitude': 73.9116, 'State': 'Goa', 'City': 'Old Goa', 'Description': 'The Basilica of Bom Jesus is a renowned Roman Catholic church in Old Goa, famous for its baroque architecture and intricate interior designs. Completed in 1605, it houses the tomb of St. Francis Xavier and is a UNESCO World Heritage site,', 'Architecture Style': 'showcasing the fusion of European and Indian architectural styles.'}
# Monument: Key Monastery Spiti Valley, Details: {'Latitude': 32.2978, 'Longitude': 78.0119, 'State': 'Himachal Pradesh', 'City': 'Spiti Valley', 'Description': 'Key Monastery, perched on a cliff at an elevation of 4,166 meters, is one of the oldest and most important monasteries in the Spiti Valley. Known for its stunning architecture and panoramic views, it serves as a spiritual center for Tibetan Buddhism and houses numerous ancient texts and artifacts.', 'Architecture Style': 'Key Monastery in Spiti Valley exhibits a Tibetan Buddhist architectural style, characterized by its fortress-like structure with whitewashed walls, tiered construction on a hilltop, and a blend of simplicity and spiritual symbolism, typical of Himalayan monastic architecture.'}
# Monument: Golden Temple Amritsar, Details: {'Latitude': 31.61997865, 'Longitude': 74.8765280750182, 'State': 'Punjab', 'City': 'Amritsar', 'Description': 'The Golden Temple, also known as Harmandir Sahib, is the holiest site of Sikhism, attracting millions of pilgrims', 'Architecture Style': 'Its architectural style blends Islamic, Mughal, and Rajput influences, featuring a gold-plated dome and intricately designed marble work.'}
# Monument: Khajuraho Temples, Details: {'Latitude': 24.85326945, 'Longitude': 79.9209008622041, 'State': 'Madhya Pradesh', 'City': 'Khajuraho', 'Description': 'The Khajuraho Temples are a group of stunning Hindu and Jain temples built between 950 and 1050 AD during the rule of the Chandela dynasty', 'Architecture Style': 'Nagara architectural style, characterized by soaring spires (shikharas) and detailed carvings that depict various aspects of life, including love, spirituality, and mythology.'}
# Monument: Humayunâ€™s Tomb, Details: {'Latitude': 28.5933, 'Longitude': 77.2507, 'State': 'New Delhi', 'City': 'Nizamuddin East', 'Description': "Humayun's Tomb is a UNESCO World Heritage Site, renowned for its stunning Mughal architecture and beautiful gardens. It is the final resting place of Mughal Emperor Humayun and features intricate red sandstone and white marble design.", 'Architecture Style': 'Humayun’s Tomb in Delhi exemplifies Mughal architecture, characterized by its grand scale, symmetrical layout, Persian-influenced charbagh garden, arched facades, and the use of red sandstone and white marble, marking the first significant example of Mughal imperial tomb architecture in India.'}
# Monument: Purana Qila, Details: {'Latitude': 28.6091959, 'Longitude': 77.24411112, 'State': 'Delhi', 'City': 'New Delhi', 'Description': "Purana Qila, one of the oldest forts in Delhi, showcases the remnants of ancient architecture and history, believed to be built on the site of the mythical city of Indraprastha. The fort features massive walls, gates, and an array of structures, including the grand Humayun's Tomb nearby.", 'Architecture Style': 'The fort exhibits Mughal and Indo-Islamic architectural styles, characterized by its imposing sandstone walls, arched gateways, and a blend of Persian and Indian architectural elements.'}
# Monument: Qutub Minar, Details: {'Latitude': 28.524413, 'Longitude': 77.18545014, 'State': 'Delhi', 'City': 'New Delhi', 'Description': 'Qutub Minar is a UNESCO World Heritage Site and one of the tallest brick minarets in the world, standing at 73 meters. Constructed in the 12th century, it features intricate carvings and inscriptions, reflecting the architectural excellence of the Indo-Islamic period.', 'Architecture Style': 'The minaret showcases Indo-Islamic architecture, characterized by its red sandstone and marble construction, detailed calligraphy, and intricate geometric patterns that blend Persian and Indian design elements.'}
# Monument: Gateway of India Mumbai, Details: {'Latitude': 18.9225901, 'Longitude': 72.8343353748536, 'State': 'Maharashtra', 'City': 'Mumbai', 'Description': "he Gateway of India, built in 1924, is a monumental archway overlooking the Arabian Sea, symbolizing British colonialism's arrival and departure in India.", 'Architecture Style': 'Indo-Saracenic architecture, blending elements of Hindu and Muslim styles with traces of Roman and Gothic influences.'}
# Monument: Fatehpur Sikri, Details: {'Latitude': 27.0911655, 'Longitude': 77.6623984, 'State': 'Uttar Pradesh', 'City': ' Fatehpur Sikri', 'Description': "Fatehpur Sikri, a UNESCO World Heritage Site, was founded by Mughal Emperor Akbar in the late 16th century as a capital city. It features stunning red sandstone buildings, intricate carvings, and impressive monuments, including the Buland Darwaza and the Jama Masjid, showcasing Akbar's vision of a harmonious empire.", 'Architecture Style': 'The site exemplifies Mughal architecture, characterized by red sandstone structures, ornate inlay work, and a harmonious blend of Persian, Indian, and Islamic design elements.'}
# Monument: Mahabalipuram , Details: {'Latitude': 12.6208, 'Longitude': 80.1945, 'State': 'Tamil Nadu', 'City': 'Mahabalipuram (Mamallapuram)', 'Description': 'Mahabalipuram is a UNESCO World Heritage Site known for its ancient rock-cut temples, intricate stone carvings, and the famous Shore Temple, all dating back to the Pallava dynasty. It features monuments like cave temples, monolithic rathas, and bas-relief sculptures.', 'Architecture Style': 'The site showcases Dravidian architecture with rock-cut and monolithic temple designs, influenced by Pallava artistry.'}
# Monument: Jaisalmer Fort, Details: {'Latitude': 26.9125, 'Longitude': 70.9126, 'State': 'Rajasthan', 'City': 'Jaisalmer', 'Description': 'Jaisalmer Fort, also known as Sonar Quila, is a massive yellow sandstone fortress that seems to glow in the sunlight, earning it the name "Golden Fort." It houses palaces, temples, and havelis within its walls and is a living fort, with people still residing inside.', 'Architecture Style': 'The fort showcases Rajasthani architecture with a blend of Islamic and Rajput design elements, built with intricately carved sandstone.'}
# Monument: Se Cathedral Goa, Details: {'Latitude': 15.50378315, 'Longitude': 73.91227414, 'State': 'Goa', 'City': 'Old Goa', 'Description': 'The Se Cathedral, one of the largest churches in Asia, is renowned for its magnificent architecture and historical significance, dedicated to Saint Catherine of Alexandria. Built in the 16th century, it features a stunning altar and impressive interiors, reflecting the influence of Portuguese colonial architecture.', 'Architecture Style': 'The Se Cathedral showcases Mannerist architecture, characterized by its large scale, simple yet grand design, and a blend of Gothic and Renaissance elements.'}
# Monument:  Meenakshi Temple, Details: {'Latitude': 12.8749691, 'Longitude': 77.5950421, 'State': 'Tamil Nadu', 'City': 'Madurai', 'Description': 'The Meenakshi Temple is an ancient and iconic Hindu temple dedicated to Goddess Meenakshi and Lord Sundareswarar. It is famous for its towering gopurams (gateway towers) adorned with intricate carvings and vibrant sculptures.', 'Architecture Style': 'Dravidian architecture, known for its monumental towers, intricate stone carvings, and elaborate sculptures depicting mythological figures.'}
# Monument: Hampi-Stone Chariot, Details: {'Latitude': 15.3423, 'Longitude': 76.4758, 'State': 'Karnataka', 'City': 'Hampi', 'Description': 'The Stone Chariot in Hampi is an iconic monument representing the grandeur of the Vijayanagara Empire, intricately carved from a single granite block. It stands as a temple chariot near the Vittala Temple, symbolizing the rich architectural and cultural heritage of Hampi.', 'Architecture Style': 'The Stone Chariot showcases Dravidian architecture, characterized by elaborate stone carvings, detailed sculptures, and a monumental design typical of the Vijayanagara style.'}
# Monument: Jaisalmer Fort, Details: {'Latitude': 26.9125, 'Longitude': 70.9126, 'State': 'Rajasthan', 'City': 'Jaisalmer', 'Description': 'Jaisalmer Fort, also known as Sonar Quila, is a massive yellow sandstone fortress that seems to glow in the sunlight, earning it the name "Golden Fort." It houses palaces, temples, and havelis within its walls and is a living fort, with people still residing inside.', 'Architecture Style': 'The fort showcases Rajasthani architecture with a blend of Islamic and Rajput design elements, built with intricately carved sandstone.'}
# Monument: Kamakhya Temple, Details: {'Latitude': 26.1664, 'Longitude': 91.7052, 'State': 'Assam', 'City': 'Guwahati', 'Description': 'Kamakhya Temple is an important Hindu shrine dedicated to the goddess Kamakhya, located on the Nilachal Hill in Guwahati. Known for its unique worship rituals and tantric traditions, it is a major pilgrimage site, especially during the annual Ambubachi Mela.', 'Architecture Style': 'The Kamakhya Temple, located in Assam, showcases a blend of Nilachal architectural style with influences of traditional Assamese temple architecture, featuring beehive-shaped domes, sculpted panels, and intricately carved stone structures.'}
# Monument: Gateway of India Mumbai, Details: {'Latitude': 18.9225901, 'Longitude': 72.8343353748536, 'State': 'Maharashtra', 'City': 'Mumbai', 'Description': "he Gateway of India, built in 1924, is a monumental archway overlooking the Arabian Sea, symbolizing British colonialism's arrival and departure in India.", 'Architecture Style': 'Indo-Saracenic architecture, blending elements of Hindu and Muslim styles with traces of Roman and Gothic influences.'}
# Monument: Ajanta & Ellora Caves, Details: {'Latitude': 20.534033, 'Longitude': 75.748283, 'State': 'Maharashtra', 'City': 'Aurangabad', 'Description': "The Ajanta Caves showcase Buddhist artistry from the 2nd century BCE to the 6th century CE, while the Ellora Caves, representing Hindu, Buddhist, and Jain traditions, date from the 5th to the 10th century CE, highlighting the region's rich cultural heritage.", 'Architecture Style': 'The Ajanta and Ellora Caves are UNESCO World Heritage Sites, featuring intricate rock-cut architecture and stunning frescoes'}
# Monument: Amer Fort Jaipur, Details: {'Latitude': 26.9854753, 'Longitude': 75.853973, 'State': 'Rajasthan', 'City': 'Jaipur', 'Description': 'Amer Fort, also known as Amber Fort, is a majestic fort', 'Architecture Style': "Hindu and Mughal architectural styles, it features intricate carvings, stunning courtyards, and beautiful gardens, showcasing the grandeur of Rajasthan's royal heritage."}
# Monument: Golconda Fort Hyderabad, Details: {'Latitude': 17.3833665, 'Longitude': 78.4010991, 'State': 'Telangana', 'City': 'Hyderabad', 'Description': 'Golconda Fort is a historic fortress renowned for its impressive architecture, sprawling complex, and strategic location atop a hill. Built during the Qutb Shahi dynasty, it features magnificent gates, palaces, and a unique acoustic system, showcasing the ingenuity of ancient engineering.', 'Architecture Style': 'The fort exhibits Indo-Islamic architecture, characterized by its massive stone walls, intricate carvings, and a blend of Persian and Indian architectural elements.'}
# Monument: Golden Temple Amritsar, Details: {'Latitude': 31.61997865, 'Longitude': 74.8765280750182, 'State': 'Punjab', 'City': 'Amritsar', 'Description': 'The Golden Temple, also known as Harmandir Sahib, is the holiest site of Sikhism, attracting millions of pilgrims', 'Architecture Style': 'Its architectural style blends Islamic, Mughal, and Rajput influences, featuring a gold-plated dome and intricately designed marble work.'}
# Monument: Sikandra Agra, Details: {'Latitude': 27.21273, 'Longitude': 77.9501491, 'State': 'Uttar Pradesh', 'City': 'Agra', 'Description': "Sikandra is the mausoleum of Emperor Akbar, set in a vast garden and known for its unique blend of Islamic and Hindu architectural styles. The structure features intricate inlay work and a grand entrance flanked by beautiful gardens, symbolizing the emperor's secular vision.", 'Architecture Style': 'Sikandra exemplifies Mughal architecture, characterized by its large dome, red sandstone, and intricate geometric and floral motifs, along with a fusion of Persian, Indian, and Islamic design elements.'}
# Monument: Charminar Hyderabad, Details: {'Latitude': 17.3616024, 'Longitude': 78.4746421377396, 'State': 'Telangana', 'City': 'Hyderabad', 'Description': 'The Charminar is a grand monument built in 1591 by Sultan Muhammad Quli Qutb Shah to commemorate the end of a deadly plague.', 'Architecture Style': 'A perfect example of Indo-Islamic architecture, blending Persian, Mughal, and Hindu design elements.'}
# Monument: Hampi-Stone Chariot, Details: {'Latitude': 15.3423, 'Longitude': 76.4758, 'State': 'Karnataka', 'City': 'Hampi', 'Description': 'The Stone Chariot in Hampi is an iconic monument representing the grandeur of the Vijayanagara Empire, intricately carved from a single granite block. It stands as a temple chariot near the Vittala Temple, symbolizing the rich architectural and cultural heritage of Hampi.', 'Architecture Style': 'The Stone Chariot showcases Dravidian architecture, characterized by elaborate stone carvings, detailed sculptures, and a monumental design typical of the Vijayanagara style.'}
# Monument: City Palace Udaipur, Details: {'Latitude': 24.5764662, 'Longitude': 73.6835836, 'State': 'Rajasthan', 'City': 'Udaipur', 'Description': 'The City Palace in Udaipur, built by Maharana Udai Singh II in 1559, is a grand complex overlooking Lake Pichola.', 'Architecture Style': 'Its architecture is a blend of Rajasthani and Mughal styles, featuring ornate balconies, towers, and domes that provide a panoramic view of the city and lake.'}
# Monument: Mahabodhi Temple , Details: {'Latitude': 24.69593025, 'Longitude': 84.99139028, 'State': 'Bihar', 'City': 'Bodh Gaya', 'Description': 'The Mahabodhi Temple is a UNESCO World Heritage Site, renowned as the location where Siddhartha Gautama attained enlightenment under the Bodhi tree. The temple features a grand structure with a towering pyramidal spire and intricate carvings, attracting pilgrims and tourists from around the world.', 'Architecture Style': 'The temple showcases Buddhist architecture, characterized by its tall stupas, intricate stone carvings, and an overall layout that reflects traditional Indian temple design.'}
# Monument: Humayunâ€™s Tomb, Details: {'Latitude': 28.5933, 'Longitude': 77.2507, 'State': 'New Delhi', 'City': 'Nizamuddin East', 'Description': "Humayun's Tomb is a UNESCO World Heritage Site, renowned for its stunning Mughal architecture and beautiful gardens. It is the final resting place of Mughal Emperor Humayun and features intricate red sandstone and white marble design.", 'Architecture Style': 'Humayun’s Tomb in Delhi exemplifies Mughal architecture, characterized by its grand scale, symmetrical layout, Persian-influenced charbagh garden, arched facades, and the use of red sandstone and white marble, marking the first significant example of Mughal imperial tomb architecture in India.'}
# Monument: Kashi Vishwanath , Details: {'Latitude': 25.3109, 'Longitude': 83.0107, 'State': 'Uttar Pradesh', 'City': 'Varanasi', 'Description': 'Kashi Vishwanath Temple is one of the most revered Hindu temples dedicated to Lord Shiva, located in the sacred city of Varanasi. Renowned for its stunning architecture and spiritual significance, it attracts millions of pilgrims and tourists each year.', 'Architecture Style': 'The Kashi Vishwanath Temple in Varanasi features a blend of Nagara architectural style, characterized by its towering spires (shikharas), intricate carvings, and the distinctive gold-plated spire on the main sanctum, symbolizing the rich heritage of North Indian temple architecture.'}
# Monument:  India Gate New Delhi, Details: {'Latitude': 28.6129332, 'Longitude': 77.2294928204987, 'State': 'Delhi', 'City': 'New Delhi', 'Description': 'India Gate is a majestic war memorial located in New Delhi, built in honor of Indian soldiers who died in World War I and the Third Anglo-Afghan War.', 'Architecture Style': 'Triumphal arch design inspired by classical European architecture, similar to the Arc de Triomphe in Paris.'}
# Monument: City Palace Udaipur, Details: {'Latitude': 24.5764662, 'Longitude': 73.6835836, 'State': 'Rajasthan', 'City': 'Udaipur', 'Description': 'The City Palace in Udaipur, built by Maharana Udai Singh II in 1559, is a grand complex overlooking Lake Pichola.', 'Architecture Style': 'Its architecture is a blend of Rajasthani and Mughal styles, featuring ornate balconies, towers, and domes that provide a panoramic view of the city and lake.'}
# Monument: Shivaji Terminus, Details: {'Latitude': 16.7027362, 'Longitude': 74.2376798, 'State': 'Maharashtra', 'City': 'Mumbai', 'Description': 'Chhatrapati Shivaji Maharaj Terminus, formerly known as Victoria Terminus, is an iconic railway station and a UNESCO World Heritage Site, celebrated for its stunning Victorian Gothic architecture. The station serves as a central hub for rail transport in Mumbai and is renowned for its intricate design and historical significance.', 'Architecture Style': 'The station showcases Victorian Gothic architecture, characterized by its pointed arches, ornate carvings, and a blend of Indian elements, including domes and chhatris (elevated dome-shaped pavilions).'}
# Monument: Red Fort, Details: {'Latitude': 28.65608095, 'Longitude': 77.24079592, 'State': 'Delhi', 'City': 'New  Delhi', 'Description': "The Red Fort, a UNESCO World Heritage Site, is a symbol of India's rich history and architectural grandeur, built by Mughal Emperor Shah Jahan in the 17th century. Its massive red sandstone walls, stunning gardens, and intricate architecture serve as a reminder of Mughal artistry and power.", 'Architecture Style': 'The fort showcases Mughal architecture, characterized by its massive walls, elegant domes, and intricate carvings, blending Persian, Timurid, and Indian architectural elements.'}
# Monument: Gateway of India Mumbai, Details: {'Latitude': 18.9225901, 'Longitude': 72.8343353748536, 'State': 'Maharashtra', 'City': 'Mumbai', 'Description': "he Gateway of India, built in 1924, is a monumental archway overlooking the Arabian Sea, symbolizing British colonialism's arrival and departure in India.", 'Architecture Style': 'Indo-Saracenic architecture, blending elements of Hindu and Muslim styles with traces of Roman and Gothic influences.'}
# Monument: Mysore Palace, Details: {'Latitude': 12.30521965, 'Longitude': 76.65538463, 'State': 'Karnataka', 'City': 'Mysuru (Mysore)', 'Description': 'Mysore Palace, also known as Amba Vilas Palace, is a stunning example of Indo-Saracenic architecture, showcasing the opulence of the Wodeyar dynasty. The palace is adorned with intricate carvings, vibrant stained glass, and exquisite arches, drawing millions of visitors every year.', 'Architecture Style': 'The palace features Indo-Saracenic architecture, characterized by a blend of Hindu, Muslim, Gothic, and Rajput styles, with prominent domes, spires, and ornate decorations.'}
# Monument: Mysore Palace, Details: {'Latitude': 12.30521965, 'Longitude': 76.65538463, 'State': 'Karnataka', 'City': 'Mysuru (Mysore)', 'Description': 'Mysore Palace, also known as Amba Vilas Palace, is a stunning example of Indo-Saracenic architecture, showcasing the opulence of the Wodeyar dynasty. The palace is adorned with intricate carvings, vibrant stained glass, and exquisite arches, drawing millions of visitors every year.', 'Architecture Style': 'The palace features Indo-Saracenic architecture, characterized by a blend of Hindu, Muslim, Gothic, and Rajput styles, with prominent domes, spires, and ornate decorations.'}
# Monument: Agra Fort, Details: {'Latitude': 27.1798258, 'Longitude': 78.0208222732058, 'State': 'Uttar Pradesh', 'City': 'Agra', 'Description': 'Agra Fort is a massive red sandstone fortress built by Emperor Akbar in 1565. It served as the main residence of the Mughal emperors until 1638. The fort encompasses a collection of palaces, halls, and mosques.', 'Architecture Style': 'Indo-Islamic architecture, blending Persian, Timurid, and Indian influences, with large courtyards, intricate marble inlays, and grand arches.'}
# Monument: Humayunâ€™s Tomb, Details: {'Latitude': 28.5933, 'Longitude': 77.2507, 'State': 'New Delhi', 'City': 'Nizamuddin East', 'Description': "Humayun's Tomb is a UNESCO World Heritage Site, renowned for its stunning Mughal architecture and beautiful gardens. It is the final resting place of Mughal Emperor Humayun and features intricate red sandstone and white marble design.", 'Architecture Style': 'Humayun’s Tomb in Delhi exemplifies Mughal architecture, characterized by its grand scale, symmetrical layout, Persian-influenced charbagh garden, arched facades, and the use of red sandstone and white marble, marking the first significant example of Mughal imperial tomb architecture in India.'}
# Monument: Gingee Fort Villupuram, Details: {'Latitude': 12.2524, 'Longitude': 79.4258, 'State': 'Tamil Nadu', 'City': 'Villupuram', 'Description': 'Gingee Fort, also known as Senji Fort, is a historic fort complex famous for its massive structures and natural landscape, situated on three hills. It features temples, granaries, and palaces, reflecting its significance as a strategic military site during various dynasties.', 'Architecture Style': 'The fort showcases a blend of Dravidian and Indo-Islamic architectural styles, characterized by rock-cut architecture, sturdy walls, and intricate stone carvings.'}
# Monument:  Meenakshi Temple, Details: {'Latitude': 12.8749691, 'Longitude': 77.5950421, 'State': 'Tamil Nadu', 'City': 'Madurai', 'Description': 'The Meenakshi Temple is an ancient and iconic Hindu temple dedicated to Goddess Meenakshi and Lord Sundareswarar. It is famous for its towering gopurams (gateway towers) adorned with intricate carvings and vibrant sculptures.', 'Architecture Style': 'Dravidian architecture, known for its monumental towers, intricate stone carvings, and elaborate sculptures depicting mythological figures.'}
# Monument: Gingee Fort Villupuram, Details: {'Latitude': 12.2524, 'Longitude': 79.4258, 'State': 'Tamil Nadu', 'City': 'Villupuram', 'Description': 'Gingee Fort, also known as Senji Fort, is a historic fort complex famous for its massive structures and natural landscape, situated on three hills. It features temples, granaries, and palaces, reflecting its significance as a strategic military site during various dynasties.', 'Architecture Style': 'The fort showcases a blend of Dravidian and Indo-Islamic architectural styles, characterized by rock-cut architecture, sturdy walls, and intricate stone carvings.'}
# Monument: Fatehpur Sikri, Details: {'Latitude': 27.0911655, 'Longitude': 77.6623984, 'State': 'Uttar Pradesh', 'City': ' Fatehpur Sikri', 'Description': "Fatehpur Sikri, a UNESCO World Heritage Site, was founded by Mughal Emperor Akbar in the late 16th century as a capital city. It features stunning red sandstone buildings, intricate carvings, and impressive monuments, including the Buland Darwaza and the Jama Masjid, showcasing Akbar's vision of a harmonious empire.", 'Architecture Style': 'The site exemplifies Mughal architecture, characterized by red sandstone structures, ornate inlay work, and a harmonious blend of Persian, Indian, and Islamic design elements.'}
# Monument: Hampi-Stone Chariot, Details: {'Latitude': 15.3423, 'Longitude': 76.4758, 'State': 'Karnataka', 'City': 'Hampi', 'Description': 'The Stone Chariot in Hampi is an iconic monument representing the grandeur of the Vijayanagara Empire, intricately carved from a single granite block. It stands as a temple chariot near the Vittala Temple, symbolizing the rich architectural and cultural heritage of Hampi.', 'Architecture Style': 'The Stone Chariot showcases Dravidian architecture, characterized by elaborate stone carvings, detailed sculptures, and a monumental design typical of the Vijayanagara style.'}
# Monument: Amer Fort Jaipur, Details: {'Latitude': 26.9854753, 'Longitude': 75.853973, 'State': 'Rajasthan', 'City': 'Jaipur', 'Description': 'Amer Fort, also known as Amber Fort, is a majestic fort', 'Architecture Style': "Hindu and Mughal architectural styles, it features intricate carvings, stunning courtyards, and beautiful gardens, showcasing the grandeur of Rajasthan's royal heritage."}
# Monument: Mahabodhi Temple , Details: {'Latitude': 24.69593025, 'Longitude': 84.99139028, 'State': 'Bihar', 'City': 'Bodh Gaya', 'Description': 'The Mahabodhi Temple is a UNESCO World Heritage Site, renowned as the location where Siddhartha Gautama attained enlightenment under the Bodhi tree. The temple features a grand structure with a towering pyramidal spire and intricate carvings, attracting pilgrims and tourists from around the world.', 'Architecture Style': 'The temple showcases Buddhist architecture, characterized by its tall stupas, intricate stone carvings, and an overall layout that reflects traditional Indian temple design.'}
# Monument: Basilica of Bom Jesus, Details: {'Latitude': 15.5009, 'Longitude': 73.9116, 'State': 'Goa', 'City': 'Old Goa', 'Description': 'The Basilica of Bom Jesus is a renowned Roman Catholic church in Old Goa, famous for its baroque architecture and intricate interior designs. Completed in 1605, it houses the tomb of St. Francis Xavier and is a UNESCO World Heritage site,', 'Architecture Style': 'showcasing the fusion of European and Indian architectural styles.'}
# Monument: Sanchi Stupa, Details: {'Latitude': 23.4806919, 'Longitude': 77.73629684, 'State': 'Madhya Pradesh', 'City': 'The Sanchi Stupa is a UNESCO World Heritage Site, renowned for its ancient Buddhist architecture and historical significance. Built during the Mauryan period, it features a large hemispherical dome and intricately carved gateways, symbolizing the importance of Buddhist teachings and the life of Buddha.', 'Description': 'The stupa exemplifies Buddhist architecture, characterized by its dome-shaped structure, elaborate stone carvings, and symbolic representation of the Buddha’s teachings.', 'Architecture Style': nan}
# Monument: Mahabalipuram , Details: {'Latitude': 12.6208, 'Longitude': 80.1945, 'State': 'Tamil Nadu', 'City': 'Mahabalipuram (Mamallapuram)', 'Description': 'Mahabalipuram is a UNESCO World Heritage Site known for its ancient rock-cut temples, intricate stone carvings, and the famous Shore Temple, all dating back to the Pallava dynasty. It features monuments like cave temples, monolithic rathas, and bas-relief sculptures.', 'Architecture Style': 'The site showcases Dravidian architecture with rock-cut and monolithic temple designs, influenced by Pallava artistry.'}
# Monument:  Meenakshi Temple, Details: {'Latitude': 12.8749691, 'Longitude': 77.5950421, 'State': 'Tamil Nadu', 'City': 'Madurai', 'Description': 'The Meenakshi Temple is an ancient and iconic Hindu temple dedicated to Goddess Meenakshi and Lord Sundareswarar. It is famous for its towering gopurams (gateway towers) adorned with intricate carvings and vibrant sculptures.', 'Architecture Style': 'Dravidian architecture, known for its monumental towers, intricate stone carvings, and elaborate sculptures depicting mythological figures.'}
# Monument: Sun Temple Konark, Details: {'Latitude': 19.8875639, 'Longitude': 86.09448945, 'State': 'Odisha', 'City': 'Konark', 'Description': 'The Sun Temple in Konark, a UNESCO World Heritage Site, is renowned for its stunning architecture, designed as a colossal chariot for the sun god Surya, drawn by seven horses. Its intricate carvings and sculptures depict various aspects of life, spirituality, and the cosmos, symbolizing the grandeur of Kalinga architecture.', 'Architecture Style': 'The temple exemplifies Kalinga architecture, characterized by its intricate stone carvings, ornate sculptures, and the unique chariot-like structure.'}
# Monument: Dilwara Temples, Details: {'Latitude': 24.6094, 'Longitude': 72.723, 'State': 'Rajasthan', 'City': 'Mount Abu', 'Description': 'The Dilwara Temples are renowned Jain temples famous for their stunning marble architecture and intricate carvings. Built between the 11th and 13th centuries, these temples serve as a significant pilgrimage site, showcasing exceptional craftsmanship that reflects the spiritual devotion of the Jain community.', 'Architecture Style': 'The temples exhibit Indo-Aryan architecture, characterized by exquisite marble work, detailed sculptures, and ornate pillars that highlight the artistry of Jain builders.'}
# Monument: Golden Temple Amritsar, Details: {'Latitude': 31.61997865, 'Longitude': 74.8765280750182, 'State': 'Punjab', 'City': 'Amritsar', 'Description': 'The Golden Temple, also known as Harmandir Sahib, is the holiest site of Sikhism, attracting millions of pilgrims', 'Architecture Style': 'Its architectural style blends Islamic, Mughal, and Rajput influences, featuring a gold-plated dome and intricately designed marble work.'}
# Monument: Lotus Temple, Details: {'Latitude': 28.5535, 'Longitude': 77.2588, 'State': 'Delhi', 'City': 'New Delhi', 'Description': "The Lotus Temple, located in New Delhi, is a Bahá'í House of Worship known for its distinctive lotus-shaped design.", 'Architecture Style': 'It exemplifies modern architectural style with its 27 free-standing marble-clad petals, symbolizing purity and unity, inviting people of all faiths to meditate and reflect in a serene environment.'}
# Monument: Brihadisvara Temple, Details: {'Latitude': 10.78257995, 'Longitude': 79.13138189, 'State': 'Tamil Nadu', 'City': 'Thanjavur', 'Description': "The Brihadisvara Temple, a UNESCO World Heritage Site, is a magnificent example of Dravidian architecture and a testament to the Chola dynasty's grandeur. Built in the 11th century, it features a massive temple complex with intricate sculptures, towering gopurams (gateway towers), and a monumental vimana (temple tower).", 'Architecture Style': 'The temple showcases Dravidian architecture, characterized by its towering vimana, intricate stone carvings, and grand scale, reflecting the artistic and engineering prowess of the Chola period.'}
# Monument: Purana Qila, Details: {'Latitude': 28.6091959, 'Longitude': 77.24411112, 'State': 'Delhi', 'City': 'New Delhi', 'Description': "Purana Qila, one of the oldest forts in Delhi, showcases the remnants of ancient architecture and history, believed to be built on the site of the mythical city of Indraprastha. The fort features massive walls, gates, and an array of structures, including the grand Humayun's Tomb nearby.", 'Architecture Style': 'The fort exhibits Mughal and Indo-Islamic architectural styles, characterized by its imposing sandstone walls, arched gateways, and a blend of Persian and Indian architectural elements.'}
# Monument: City Palace Udaipur, Details: {'Latitude': 24.5764662, 'Longitude': 73.6835836, 'State': 'Rajasthan', 'City': 'Udaipur', 'Description': 'The City Palace in Udaipur, built by Maharana Udai Singh II in 1559, is a grand complex overlooking Lake Pichola.', 'Architecture Style': 'Its architecture is a blend of Rajasthani and Mughal styles, featuring ornate balconies, towers, and domes that provide a panoramic view of the city and lake.'}
# Monument: Fatehpur Sikri, Details: {'Latitude': 27.0911655, 'Longitude': 77.6623984, 'State': 'Uttar Pradesh', 'City': ' Fatehpur Sikri', 'Description': "Fatehpur Sikri, a UNESCO World Heritage Site, was founded by Mughal Emperor Akbar in the late 16th century as a capital city. It features stunning red sandstone buildings, intricate carvings, and impressive monuments, including the Buland Darwaza and the Jama Masjid, showcasing Akbar's vision of a harmonious empire.", 'Architecture Style': 'The site exemplifies Mughal architecture, characterized by red sandstone structures, ornate inlay work, and a harmonious blend of Persian, Indian, and Islamic design elements.'}
# Monument: Red Fort, Details: {'Latitude': 28.65608095, 'Longitude': 77.24079592, 'State': 'Delhi', 'City': 'New  Delhi', 'Description': "The Red Fort, a UNESCO World Heritage Site, is a symbol of India's rich history and architectural grandeur, built by Mughal Emperor Shah Jahan in the 17th century. Its massive red sandstone walls, stunning gardens, and intricate architecture serve as a reminder of Mughal artistry and power.", 'Architecture Style': 'The fort showcases Mughal architecture, characterized by its massive walls, elegant domes, and intricate carvings, blending Persian, Timurid, and Indian architectural elements.'}
# Monument: Golden Temple Amritsar, Details: {'Latitude': 31.61997865, 'Longitude': 74.8765280750182, 'State': 'Punjab', 'City': 'Amritsar', 'Description': 'The Golden Temple, also known as Harmandir Sahib, is the holiest site of Sikhism, attracting millions of pilgrims', 'Architecture Style': 'Its architectural style blends Islamic, Mughal, and Rajput influences, featuring a gold-plated dome and intricately designed marble work.'}
# Monument: Mahabalipuram , Details: {'Latitude': 12.6208, 'Longitude': 80.1945, 'State': 'Tamil Nadu', 'City': 'Mahabalipuram (Mamallapuram)', 'Description': 'Mahabalipuram is a UNESCO World Heritage Site known for its ancient rock-cut temples, intricate stone carvings, and the famous Shore Temple, all dating back to the Pallava dynasty. It features monuments like cave temples, monolithic rathas, and bas-relief sculptures.', 'Architecture Style': 'The site showcases Dravidian architecture with rock-cut and monolithic temple designs, influenced by Pallava artistry.'}
# Monument: Sun Temple Konark, Details: {'Latitude': 19.8875639, 'Longitude': 86.09448945, 'State': 'Odisha', 'City': 'Konark', 'Description': 'The Sun Temple in Konark, a UNESCO World Heritage Site, is renowned for its stunning architecture, designed as a colossal chariot for the sun god Surya, drawn by seven horses. Its intricate carvings and sculptures depict various aspects of life, spirituality, and the cosmos, symbolizing the grandeur of Kalinga architecture.', 'Architecture Style': 'The temple exemplifies Kalinga architecture, characterized by its intricate stone carvings, ornate sculptures, and the unique chariot-like structure.'}
# Monument: Mehrangarh Fort Jodhpur , Details: {'Latitude': 26.2995407, 'Longitude': 73.0195132, 'State': 'Rajasthan', 'City': 'Jodhpur', 'Description': 'Mehrangarh Fort, one of the largest forts in India, is perched on a hilltop and offers breathtaking views of the Blue City of Jodhpur. Built in the 15th century, it features impressive palaces, museums, and intricate carvings that reflect the grandeur of the Rajputana era.', 'Architecture Style': 'The fort showcases Rajput architecture, characterized by its massive walls, intricate jharokhas (overhanging enclosed balconies), and detailed sandstone carvings.'}
# Monument: Mahabalipuram , Details: {'Latitude': 12.6208, 'Longitude': 80.1945, 'State': 'Tamil Nadu', 'City': 'Mahabalipuram (Mamallapuram)', 'Description': 'Mahabalipuram is a UNESCO World Heritage Site known for its ancient rock-cut temples, intricate stone carvings, and the famous Shore Temple, all dating back to the Pallava dynasty. It features monuments like cave temples, monolithic rathas, and bas-relief sculptures.', 'Architecture Style': 'The site showcases Dravidian architecture with rock-cut and monolithic temple designs, influenced by Pallava artistry.'}
# Monument: Mysore Palace, Details: {'Latitude': 12.30521965, 'Longitude': 76.65538463, 'State': 'Karnataka', 'City': 'Mysuru (Mysore)', 'Description': 'Mysore Palace, also known as Amba Vilas Palace, is a stunning example of Indo-Saracenic architecture, showcasing the opulence of the Wodeyar dynasty. The palace is adorned with intricate carvings, vibrant stained glass, and exquisite arches, drawing millions of visitors every year.', 'Architecture Style': 'The palace features Indo-Saracenic architecture, characterized by a blend of Hindu, Muslim, Gothic, and Rajput styles, with prominent domes, spires, and ornate decorations.'}
# Monument: Mahabalipuram , Details: {'Latitude': 12.6208, 'Longitude': 80.1945, 'State': 'Tamil Nadu', 'City': 'Mahabalipuram (Mamallapuram)', 'Description': 'Mahabalipuram is a UNESCO World Heritage Site known for its ancient rock-cut temples, intricate stone carvings, and the famous Shore Temple, all dating back to the Pallava dynasty. It features monuments like cave temples, monolithic rathas, and bas-relief sculptures.', 'Architecture Style': 'The site showcases Dravidian architecture with rock-cut and monolithic temple designs, influenced by Pallava artistry.'}
# Monument: Fatehpur Sikri, Details: {'Latitude': 27.0911655, 'Longitude': 77.6623984, 'State': 'Uttar Pradesh', 'City': ' Fatehpur Sikri', 'Description': "Fatehpur Sikri, a UNESCO World Heritage Site, was founded by Mughal Emperor Akbar in the late 16th century as a capital city. It features stunning red sandstone buildings, intricate carvings, and impressive monuments, including the Buland Darwaza and the Jama Masjid, showcasing Akbar's vision of a harmonious empire.", 'Architecture Style': 'The site exemplifies Mughal architecture, characterized by red sandstone structures, ornate inlay work, and a harmonious blend of Persian, Indian, and Islamic design elements.'}
# Monument: Se Cathedral Goa, Details: {'Latitude': 15.50378315, 'Longitude': 73.91227414, 'State': 'Goa', 'City': 'Old Goa', 'Description': 'The Se Cathedral, one of the largest churches in Asia, is renowned for its magnificent architecture and historical significance, dedicated to Saint Catherine of Alexandria. Built in the 16th century, it features a stunning altar and impressive interiors, reflecting the influence of Portuguese colonial architecture.', 'Architecture Style': 'The Se Cathedral showcases Mannerist architecture, characterized by its large scale, simple yet grand design, and a blend of Gothic and Renaissance elements.'}
# Monument: Mahabodhi Temple , Details: {'Latitude': 24.69593025, 'Longitude': 84.99139028, 'State': 'Bihar', 'City': 'Bodh Gaya', 'Description': 'The Mahabodhi Temple is a UNESCO World Heritage Site, renowned as the location where Siddhartha Gautama attained enlightenment under the Bodhi tree. The temple features a grand structure with a towering pyramidal spire and intricate carvings, attracting pilgrims and tourists from around the world.', 'Architecture Style': 'The temple showcases Buddhist architecture, characterized by its tall stupas, intricate stone carvings, and an overall layout that reflects traditional Indian temple design.'}
# Monument:  Hawa Mahal Jaipur , Details: {'Latitude': 26.923932, 'Longitude': 75.8268652, 'State': 'Rajasthan', 'City': 'Jaipur', 'Description': 'Hawa Mahal, also known as the "Palace of Winds," is a five-story palace made of red and pink sandstone, built in 1799 by Maharaja Sawai Pratap Singh. It features over 900 small windows (jharokhas) designed for the royal women to observe street life without being seen', 'Architecture Style': 'The architectural style blends Rajput and Mughal influences.'}
# Monument: Key Monastery Spiti Valley, Details: {'Latitude': 32.2978, 'Longitude': 78.0119, 'State': 'Himachal Pradesh', 'City': 'Spiti Valley', 'Description': 'Key Monastery, perched on a cliff at an elevation of 4,166 meters, is one of the oldest and most important monasteries in the Spiti Valley. Known for its stunning architecture and panoramic views, it serves as a spiritual center for Tibetan Buddhism and houses numerous ancient texts and artifacts.', 'Architecture Style': 'Key Monastery in Spiti Valley exhibits a Tibetan Buddhist architectural style, characterized by its fortress-like structure with whitewashed walls, tiered construction on a hilltop, and a blend of simplicity and spiritual symbolism, typical of Himalayan monastic architecture.'}
# Monument: Pattadakal, Details: {'Latitude': 15.9488, 'Longitude': 75.8164, 'State': 'Karnataka', 'City': 'Pattadakal', 'Description': "Pattadakal is a UNESCO World Heritage Site renowned for its group of 7th and 8th-century temples that display a blend of North Indian (Nagara) and South Indian (Dravidian) architectural styles, reflecting the Chalukyan dynasty's artistic achievements. It served as a royal ceremonial center for coronations.", 'Architecture Style': 'Pattadakal exhibits a fusion of Dravidian and Nagara architectural styles, with intricately carved sandstone temples.'}
# ...
# Monument: Fatehpur Sikri, Details: {'Latitude': 27.0911655, 'Longitude': 77.6623984, 'State': 'Uttar Pradesh', 'City': ' Fatehpur Sikri', 'Description': "Fatehpur Sikri, a UNESCO World Heritage Site, was founded by Mughal Emperor Akbar in the late 16th century as a capital city. It features stunning red sandstone buildings, intricate carvings, and impressive monuments, including the Buland Darwaza and the Jama Masjid, showcasing Akbar's vision of a harmonious empire.", 'Architecture Style': 'The site exemplifies Mughal architecture, characterized by red sandstone structures, ornate inlay work, and a harmonious blend of Persian, Indian, and Islamic design elements.'}
# Monument: Golden Temple Amritsar, Details: {'Latitude': 31.61997865, 'Longitude': 74.8765280750182, 'State': 'Punjab', 'City': 'Amritsar', 'Description': 'The Golden Temple, also known as Harmandir Sahib, is the holiest site of Sikhism, attracting millions of pilgrims', 'Architecture Style': 'Its architectural style blends Islamic, Mughal, and Rajput influences, featuring a gold-plated dome and intricately designed marble work.'}
# Monument: Agra Fort, Details: {'Latitude': 27.1798258, 'Longitude': 78.0208222732058, 'State': 'Uttar Pradesh', 'City': 'Agra', 'Description': 'Agra Fort is a massive red sandstone fortress built by Emperor Akbar in 1565. It served as the main residence of the Mughal emperors until 1638. The fort encompasses a collection of palaces, halls, and mosques.', 'Architecture Style': 'Indo-Islamic architecture, blending Persian, Timurid, and Indian influences, with large courtyards, intricate marble inlays, and grand arches.'}
# Monument: Victoria Memorial Kolkata, Details: {'Latitude': 22.5449557999999, 'Longitude': 88.3425544513534, 'State': 'West Bengal', 'City': 'Kolkata', 'Description': 'he Victoria Memorial is a grand marble building in Kolkata, India, dedicated to Queen Victoria.', 'Architecture Style': 'Indo-Saracenic architectural style, incorporating elements of British, Mughal, and Venetian design, surrounded by lush gardens and reflecting pools'}
# Monument: Dilwara Temples, Details: {'Latitude': 24.6094, 'Longitude': 72.723, 'State': 'Rajasthan', 'City': 'Mount Abu', 'Description': 'The Dilwara Temples are renowned Jain temples famous for their stunning marble architecture and intricate carvings. Built between the 11th and 13th centuries, these temples serve as a significant pilgrimage site, showcasing exceptional craftsmanship that reflects the spiritual devotion of the Jain community.', 'Architecture Style': 'The temples exhibit Indo-Aryan architecture, characterized by exquisite marble work, detailed sculptures, and ornate pillars that highlight the artistry of Jain builders.'}
# Monument: Amer Fort Jaipur, Details: {'Latitude': 26.9854753, 'Longitude': 75.853973, 'State': 'Rajasthan', 'City': 'Jaipur', 'Description': 'Amer Fort, also known as Amber Fort, is a majestic fort', 'Architecture Style': "Hindu and Mughal architectural styles, it features intricate carvings, stunning courtyards, and beautiful gardens, showcasing the grandeur of Rajasthan's royal heritage."}
# Monument: Hampi-Stone Chariot, Details: {'Latitude': 15.3423, 'Longitude': 76.4758, 'State': 'Karnataka', 'City': 'Hampi', 'Description': 'The Stone Chariot in Hampi is an iconic monument representing the grandeur of the Vijayanagara Empire, intricately carved from a single granite block. It stands as a temple chariot near the Vittala Temple, symbolizing the rich architectural and cultural heritage of Hampi.', 'Architecture Style': 'The Stone Chariot showcases Dravidian architecture, characterized by elaborate stone carvings, detailed sculptures, and a monumental design typical of the Vijayanagara style.'}
# Monument: Rashtrapati Bhawan, Details: {'Latitude': 28.6143, 'Longitude': 77.1994, 'State': 'Delhi', 'City': 'New Delhi', 'Description': 'Rashtrapati Bhawan, the official residence of the President of India, is an architectural marvel that combines Indian and Western styles, set within extensive gardens. Designed by architect Edwin Lutyens, it symbolizes the grandeur of colonial architecture and Indian heritage.', 'Architecture Style': 'The building features a Neo-Classical architectural style with elements of Mughal architecture, characterized by its large dome, imposing columns, and elaborate ornamental details.'}
# Monument: Jantar Mantar Jaipur, Details: {'Latitude': 26.9248, 'Longitude': 75.8246, 'State': 'Rajasthan', 'City': 'Jaipur', 'Description': 'Jantar Mantar in Jaipur is an astronomical observatory built in the 18th century, featuring a collection of architectural astronomical instruments. It is recognized for its unique structures used to measure time, predict eclipses, and track celestial bodies, and is a UNESCO World Heritage Site.', 'Architecture Style': 'The architecture style of Jantar Mantar, Jaipur, is a blend of monumental Rajasthani and Mughal elements, designed with large geometric structures for astronomical purposes.'}
# Monument: Khajuraho Temples, Details: {'Latitude': 24.85326945, 'Longitude': 79.9209008622041, 'State': 'Madhya Pradesh', 'City': 'Khajuraho', 'Description': 'The Khajuraho Temples are a group of stunning Hindu and Jain temples built between 950 and 1050 AD during the rule of the Chandela dynasty', 'Architecture Style': 'Nagara architectural style, characterized by soaring spires (shikharas) and detailed carvings that depict various aspects of life, including love, spirituality, and mythology.'}
# Monument: Humayunâ€™s Tomb, Details: {'Latitude': 28.5933, 'Longitude': 77.2507, 'State': 'New Delhi', 'City': 'Nizamuddin East', 'Description': "Humayun's Tomb is a UNESCO World Heritage Site, renowned for its stunning Mughal architecture and beautiful gardens. It is the final resting place of Mughal Emperor Humayun and features intricate red sandstone and white marble design.", 'Architecture Style': 'Humayun’s Tomb in Delhi exemplifies Mughal architecture, characterized by its grand scale, symmetrical layout, Persian-influenced charbagh garden, arched facades, and the use of red sandstone and white marble, marking the first significant example of Mughal imperial tomb architecture in India.'}
# Monument: Key Monastery Spiti Valley, Details: {'Latitude': 32.2978, 'Longitude': 78.0119, 'State': 'Himachal Pradesh', 'City': 'Spiti Valley', 'Description': 'Key Monastery, perched on a cliff at an elevation of 4,166 meters, is one of the oldest and most important monasteries in the Spiti Valley. Known for its stunning architecture and panoramic views, it serves as a spiritual center for Tibetan Buddhism and houses numerous ancient texts and artifacts.', 'Architecture Style': 'Key Monastery in Spiti Valley exhibits a Tibetan Buddhist architectural style, characterized by its fortress-like structure with whitewashed walls, tiered construction on a hilltop, and a blend of simplicity and spiritual symbolism, typical of Himalayan monastic architecture.'}
# Monument:  India Gate New Delhi, Details: {'Latitude': 28.6129332, 'Longitude': 77.2294928204987, 'State': 'Delhi', 'City': 'New Delhi', 'Description': 'India Gate is a majestic war memorial located in New Delhi, built in honor of Indian soldiers who died in World War I and the Third Anglo-Afghan War.', 'Architecture Style': 'Triumphal arch design inspired by classical European architecture, similar to the Arc de Triomphe in Paris.'}
# Monument: Se Cathedral Goa, Details: {'Latitude': 15.50378315, 'Longitude': 73.91227414, 'State': 'Goa', 'City': 'Old Goa', 'Description': 'The Se Cathedral, one of the largest churches in Asia, is renowned for its magnificent architecture and historical significance, dedicated to Saint Catherine of Alexandria. Built in the 16th century, it features a stunning altar and impressive interiors, reflecting the influence of Portuguese colonial architecture.', 'Architecture Style': 'The Se Cathedral showcases Mannerist architecture, characterized by its large scale, simple yet grand design, and a blend of Gothic and Renaissance elements.'}
# Monument: Khajuraho Temples, Details: {'Latitude': 24.85326945, 'Longitude': 79.9209008622041, 'State': 'Madhya Pradesh', 'City': 'Khajuraho', 'Description': 'The Khajuraho Temples are a group of stunning Hindu and Jain temples built between 950 and 1050 AD during the rule of the Chandela dynasty', 'Architecture Style': 'Nagara architectural style, characterized by soaring spires (shikharas) and detailed carvings that depict various aspects of life, including love, spirituality, and mythology.'}
# Monument: Nalanda, Details: {'Latitude': 25.1364914, 'Longitude': 85.44365465, 'State': 'Bihar', 'City': 'Nalanda', 'Description': 'Nalanda was an ancient center of learning and one of the first residential universities in the world, flourishing from the 5th to the 12th century. The site contains ruins of numerous monasteries, temples, and a large library, reflecting its significance in Buddhist education and scholarship.', 'Architecture Style': 'The ruins of Nalanda exhibit Buddhist architectural style, characterized by monastic complexes with elaborate stupas, intricately carved stone structures, and symmetrical layouts typical of ancient Indian architecture.'}
# Monument: Qutub Minar, Details: {'Latitude': 28.524413, 'Longitude': 77.18545014, 'State': 'Delhi', 'City': 'New Delhi', 'Description': 'Qutub Minar is a UNESCO World Heritage Site and one of the tallest brick minarets in the world, standing at 73 meters. Constructed in the 12th century, it features intricate carvings and inscriptions, reflecting the architectural excellence of the Indo-Islamic period.', 'Architecture Style': 'The minaret showcases Indo-Islamic architecture, characterized by its red sandstone and marble construction, detailed calligraphy, and intricate geometric patterns that blend Persian and Indian design elements.'}
# Monument: Jantar Mantar Jaipur, Details: {'Latitude': 26.9248, 'Longitude': 75.8246, 'State': 'Rajasthan', 'City': 'Jaipur', 'Description': 'Jantar Mantar in Jaipur is an astronomical observatory built in the 18th century, featuring a collection of architectural astronomical instruments. It is recognized for its unique structures used to measure time, predict eclipses, and track celestial bodies, and is a UNESCO World Heritage Site.', 'Architecture Style': 'The architecture style of Jantar Mantar, Jaipur, is a blend of monumental Rajasthani and Mughal elements, designed with large geometric structures for astronomical purposes.'}
# Monument: Red Fort, Details: {'Latitude': 28.65608095, 'Longitude': 77.24079592, 'State': 'Delhi', 'City': 'New  Delhi', 'Description': "The Red Fort, a UNESCO World Heritage Site, is a symbol of India's rich history and architectural grandeur, built by Mughal Emperor Shah Jahan in the 17th century. Its massive red sandstone walls, stunning gardens, and intricate architecture serve as a reminder of Mughal artistry and power.", 'Architecture Style': 'The fort showcases Mughal architecture, characterized by its massive walls, elegant domes, and intricate carvings, blending Persian, Timurid, and Indian architectural elements.'}
# Monument: Hill Palace Museum, Details: {'Latitude': 9.9526, 'Longitude': 76.3619, 'State': 'Kerala', 'City': 'Tripunithura (near Kochi)', 'Description': 'Hill Palace Museum, once the royal residence of the Cochin Maharajas, is now the largest archaeological museum in Kerala. It houses royal artifacts, historical relics, and an expansive collection of traditional Kerala architecture.', 'Architecture Style': 'The palace exhibits traditional Kerala architecture, with sloping tiled roofs, wooden carvings, and a blend of colonial influences.'}
# Monument: Humayunâ€™s Tomb, Details: {'Latitude': 28.5933, 'Longitude': 77.2507, 'State': 'New Delhi', 'City': 'Nizamuddin East', 'Description': "Humayun's Tomb is a UNESCO World Heritage Site, renowned for its stunning Mughal architecture and beautiful gardens. It is the final resting place of Mughal Emperor Humayun and features intricate red sandstone and white marble design.", 'Architecture Style': 'Humayun’s Tomb in Delhi exemplifies Mughal architecture, characterized by its grand scale, symmetrical layout, Persian-influenced charbagh garden, arched facades, and the use of red sandstone and white marble, marking the first significant example of Mughal imperial tomb architecture in India.'}
# Monument: Key Monastery Spiti Valley, Details: {'Latitude': 32.2978, 'Longitude': 78.0119, 'State': 'Himachal Pradesh', 'City': 'Spiti Valley', 'Description': 'Key Monastery, perched on a cliff at an elevation of 4,166 meters, is one of the oldest and most important monasteries in the Spiti Valley. Known for its stunning architecture and panoramic views, it serves as a spiritual center for Tibetan Buddhism and houses numerous ancient texts and artifacts.', 'Architecture Style': 'Key Monastery in Spiti Valley exhibits a Tibetan Buddhist architectural style, characterized by its fortress-like structure with whitewashed walls, tiered construction on a hilltop, and a blend of simplicity and spiritual symbolism, typical of Himalayan monastic architecture.'}
# Monument: Sikandra Agra, Details: {'Latitude': 27.21273, 'Longitude': 77.9501491, 'State': 'Uttar Pradesh', 'City': 'Agra', 'Description': "Sikandra is the mausoleum of Emperor Akbar, set in a vast garden and known for its unique blend of Islamic and Hindu architectural styles. The structure features intricate inlay work and a grand entrance flanked by beautiful gardens, symbolizing the emperor's secular vision.", 'Architecture Style': 'Sikandra exemplifies Mughal architecture, characterized by its large dome, red sandstone, and intricate geometric and floral motifs, along with a fusion of Persian, Indian, and Islamic design elements.'}
# Monument: Gateway of India Mumbai, Details: {'Latitude': 18.9225901, 'Longitude': 72.8343353748536, 'State': 'Maharashtra', 'City': 'Mumbai', 'Description': "he Gateway of India, built in 1924, is a monumental archway overlooking the Arabian Sea, symbolizing British colonialism's arrival and departure in India.", 'Architecture Style': 'Indo-Saracenic architecture, blending elements of Hindu and Muslim styles with traces of Roman and Gothic influences.'}
# Monument: Gateway of India Mumbai, Details: {'Latitude': 18.9225901, 'Longitude': 72.8343353748536, 'State': 'Maharashtra', 'City': 'Mumbai', 'Description': "he Gateway of India, built in 1924, is a monumental archway overlooking the Arabian Sea, symbolizing British colonialism's arrival and departure in India.", 'Architecture Style': 'Indo-Saracenic architecture, blending elements of Hindu and Muslim styles with traces of Roman and Gothic influences.'}
# Monument: Pattadakal, Details: {'Latitude': 15.9488, 'Longitude': 75.8164, 'State': 'Karnataka', 'City': 'Pattadakal', 'Description': "Pattadakal is a UNESCO World Heritage Site renowned for its group of 7th and 8th-century temples that display a blend of North Indian (Nagara) and South Indian (Dravidian) architectural styles, reflecting the Chalukyan dynasty's artistic achievements. It served as a royal ceremonial center for coronations.", 'Architecture Style': 'Pattadakal exhibits a fusion of Dravidian and Nagara architectural styles, with intricately carved sandstone temples.'}
# Monument: Mysore Palace, Details: {'Latitude': 12.30521965, 'Longitude': 76.65538463, 'State': 'Karnataka', 'City': 'Mysuru (Mysore)', 'Description': 'Mysore Palace, also known as Amba Vilas Palace, is a stunning example of Indo-Saracenic architecture, showcasing the opulence of the Wodeyar dynasty. The palace is adorned with intricate carvings, vibrant stained glass, and exquisite arches, drawing millions of visitors every year.', 'Architecture Style': 'The palace features Indo-Saracenic architecture, characterized by a blend of Hindu, Muslim, Gothic, and Rajput styles, with prominent domes, spires, and ornate decorations.'}
# Test Accuracy: 0.8808

# %%
from PIL import Image
import torch
import torchvision.transforms as transforms

#preprocess the input image
def preprocess_image(image_path):
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
    ])

    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)
    return image
def predict_monument(image_path, model, label_mapping, labels_df):
    image = preprocess_image(image_path)
    image = image.to(device)
    model.eval()
    with torch.no_grad():
        outputs = model(image).logits
        _, predicted_label_idx = torch.max(outputs, 1)
    predicted_label_idx = predicted_label_idx.item()
    inv_label_mapping = {v: k for k, v in label_mapping.items()}
    predicted_monument_name = inv_label_mapping[predicted_label_idx]
    # Retrieve monument details
    details = get_monument_details(predicted_monument_name, labels_df)

    return predicted_monument_name, details
# Example
image_path = '/content/tajamahal.jpg'
predicted_monument, monument_details = predict_monument(image_path, model, label_mapping, labels_df)

print(f"Predicted Monument: {predicted_monument}")
print(f"Details: {monument_details}")
# Out:
# Predicted Monument: Taj Mahal Agra
# Details: {'Latitude': 27.1750123, 'Longitude': 78.0420968366131, 'State': 'Uttara Pradesh', 'City': 'Agra', 'Description': 'The Taj Mahal is a stunning white marble mausoleum located in Agra, India. Built by Mughal Emperor Shah Jahan between 1632 and 1653, it was constructed in memory of his wife, Mumtaz Mahal.', 'Architecture Style': 'Mughal architecture with influences from Persian, Islamic, and Indian architectural elements'}

# %%
# Displaying Mahabalipuram
image_path = '/content/1729521408129.jpg'
predicted_monument, monument_details = predict_monument(image_path, model, label_mapping, labels_df)

print(f"Predicted Monument: {predicted_monument}")
print(f"Details: {monument_details}")
# Out:
# Predicted Monument: Mahabalipuram
# Details: {'Latitude': 12.6208, 'Longitude': 80.1945, 'State': 'Tamil Nadu', 'City': 'Mahabalipuram (Mamallapuram)', 'Description': 'Mahabalipuram is a UNESCO World Heritage Site known for its ancient rock-cut temples, intricate stone carvings, and the famous Shore Temple, all dating back to the Pallava dynasty. It features monuments like cave temples, monolithic rathas, and bas-relief sculptures.', 'Architecture Style': 'The site showcases Dravidian architecture with rock-cut and monolithic temple designs, influenced by Pallava artistry.'}

# %%
# Displaying Golconda Fort
image_path = '/content/golcondafort.jpg'
predicted_monument, monument_details = predict_monument(image_path, model, label_mapping, labels_df)

print(f"Predicted Monument: {predicted_monument}")
print(f"Details: {monument_details}")
# Out:
# Predicted Monument: Golconda Fort Hyderabad
# Details: {'Latitude': 17.3833665, 'Longitude': 78.4010991, 'State': 'Telangana', 'City': 'Hyderabad', 'Description': 'Golconda Fort is a historic fortress renowned for its impressive architecture, sprawling complex, and strategic location atop a hill. Built during the Qutb Shahi dynasty, it features magnificent gates, palaces, and a unique acoustic system, showcasing the ingenuity of ancient engineering.', 'Architecture Style': 'The fort exhibits Indo-Islamic architecture, characterized by its massive stone walls, intricate carvings, and a blend of Persian and Indian architectural elements.'}

# %%
# Training loop function (unchanged)
def train(model, train_loader, optimizer, criterion, num_epochs=5):
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images).logits
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

            # Calculate training accuracy during training loop
            _, preds = torch.max(outputs, 1)
            correct_train += (preds == labels).sum().item()
            total_train += labels.size(0)
        train_accuracy = correct_train / total_train * 100
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_loader):.4f}, Train Accuracy: {train_accuracy:.2f}%')
# Evaluation function
def evaluate(model, data_loader, label_mapping):
    model.eval()
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in data_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images).logits
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    accuracy = correct / total * 100
    return accuracy
# Train the model
train(model, train_loader, optimizer, criterion, num_epochs=3)
#train accuracy
train_accuracy = evaluate(model, train_loader, label_mapping)
print(f'Training Accuracy: {train_accuracy:.2f}%')
#test accuracy
test_accuracy = evaluate(model, test_loader, label_mapping)
print(f'Test Accuracy: {test_accuracy:.2f}%')
# Out:
# Epoch [1/3], Loss: 0.0164, Train Accuracy: 99.22%
# Epoch [2/3], Loss: 0.0069, Train Accuracy: 99.61%
# Epoch [3/3], Loss: 0.0054, Train Accuracy: 99.74%
# Training Accuracy: 99.74%
# Test Accuracy: 90.16%
